# %% [markdown]
# # <span style="color:red">**Challenge 2**</span>
#
# 1. Plot the distributions of GDP per capita separately for each continent.

# %%
# Loading/installing packages
# !pip install gapminder
import pandas as pd
import numpy as np
from plotnine import *
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Loading the dataset
from gapminder import gapminder

# %%
gapminder.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# Plotting the distribution of GDP per capita
p = (ggplot(gapminder, aes(x='gdpPercap', fill='continent')) + 
     geom_density(alpha=0.4))
# Show the plot
p.show()

# %% [markdown]
# 2. Transform the x-axis to a log scale and add another layer for the log transformation.

# %%
# Plotting the distribution of GDP per capita
p = (ggplot(gapminder, aes(x='gdpPercap', fill='continent')) + 
     geom_density(alpha=0.4)+ coord_trans(x='log'))
# Show the plot
p.show()

# %% [markdown]
# 3. Create boxplots of GDP per capita by continent, with and without a log scale.

# %%
p=(ggplot(gapminder, aes(x='continent', y='gdpPercap', fill='continent')) + geom_boxplot())
p.show()

# %%
p=(ggplot(gapminder, aes(x='continent', y='gdpPercap', fill='continent')) + geom_boxplot() + coord_trans(y='log'))
p.show()
